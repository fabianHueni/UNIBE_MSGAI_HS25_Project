quam saepe omnis quo ut eveniet necessitatibus voluptatem error. Repudiandae consequuntur soluta cumque aliquid sint enim accusamus, harum labore quisquam delectus.\nNulla magni voluptates alias fugit quis et molestiae, debitis non vitae ullam pariatur cumque perspiciatis repudiandae distinctio reprehenderit quo, fuga praesentium repellendus, praesentium quam dolorum ut, consectetur sapiente ipsa. Deserunt harum totam, esse fugiat obcaecati reiciendis iste dolorem quae nisi tempore blanditiis, laudantium ullam suscipit culpa. Autem excepturi et incidunt vitae, maxime quidem earum deleniti quibusdam nihil delectus nam conse ...

# %%
# 2. Set the maximum number of words for the dataset
# This parameter controls how many rows will be generated.
max_words = 1000 

# 3. Prepare the data generation
words = lorem_ipsum_source.split()
dataset_rows = []

# Ensure the requested number of words does not exceed the source text length
if max_words > len(words):
    print(f"Warning: max_words ({max_words}) exceeds the number of available words in the source text ({len(words)}).")
    print(f"The dataset will be capped at {len(words)} rows.")
    max_words = len(words)

# 4. Loop to generate each row of the dataset
for i in range(1, max_words + 1):
    # Select the first 'i' words from the source list
    current_words_list = words[:i]
    
    # Join the words to form the text for the current row
    text = " ".join(current_words_list)
    
    # Get the last word
    last_word = current_words_list[-1]
    
    # Append the generated data as a dictionary to our list
    dataset_rows.append({
        'text': text,
        'char_count': len(text),
        'word_count': i,
        'last_word': last_word
    })

# 5. Create the final pandas DataFrame
df_lorem = pd.DataFrame(dataset_rows)

# 6. Display the head and tail of the generated DataFrame to verify
print(f"Successfully generated a dataset with {len(df_lorem)} rows.")
print("\nFirst 5 rows:")
display(df_lorem.head())

print("\nLast 5 rows:")
display(df_lorem.tail())
# Out:
# Successfully generated a dataset with 1000 rows.
#
# First 5 rows:
#                           text  char_count  word_count last_word
# 0                        Lorem           5           1     Lorem
# 1                  Lorem ipsum          11           2     ipsum
# 2            Lorem ipsum dolor          17           3     dolor
# 3        Lorem ipsum dolor sit          21           4       sit
# 4  Lorem ipsum dolor sit amet,          27           5     amet,
# Last 5 rows:
#                                                   text  char_count  \
# 995  Lorem ipsum dolor sit amet, consectetur adipis...        7460
# 996  Lorem ipsum dolor sit amet, consectetur adipis...        7466
# 997  Lorem ipsum dolor sit amet, consectetur adipis...        7472
# 998  Lorem ipsum dolor sit amet, consectetur adipis...        7483
# 999  Lorem ipsum dolor sit amet, consectetur adipis...        7493
#
#      word_count   last_word
# 995         996          at
# 996         997       rerum
# 997         998       saepe
# 998         999  explicabo,
# 999        1000   inventore

# %%
# 7. Export the DataFrame to a CSV file
output_filename = '../dataset/lorem_ipsum_dataset.csv'
df_lorem.to_csv(output_filename, index=False)

print(f"DataFrame successfully exported to '{output_filename}'.")
# Out:
# DataFrame successfully exported to '../dataset/lorem_ipsum_dataset.csv'.
