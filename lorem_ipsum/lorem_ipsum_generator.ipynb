# %%
import pandas as pd
from lorem_text import lorem

# %%
# 1. Define the source "Lorem Ipsum" text
lorem_ipsum_source = lorem.paragraphs(500)

lorem_ipsum_source
# Out:
# 'Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\nQuibusdam placeat facilis accusantium fugit suscipit exercitationem nisi atque, corporis ea quaerat provident pariatur, temporibus ut corrupti quis, maxime animi dolore saepe velit quos, assumenda porro amet cumque nobis perferendis dolores labore cum itaque deleniti fugiat? Adipisci error dicta suscipit dolores repellendus asperiores, impedit adipisci numquam facere in mollitia id, pariatur inventore dolorem ullam rerum necessitatibus, cupiditate quas aut tempora sequi amet temporibus. Earum nesciunt minima incidunt soluta sed saepe quasi, facere nihil numquam blanditiis laborum, soluta molestiae maiores voluptatum sunt dicta. Nulla itaque numquam mollitia delectus sed error cumque soluta, optio laborum cum aut id expedita vero totam architecto nihil officiis exercitationem?\nRerum earum doloremque architecto aperiam quibusdam, eum id repudiandae dolor, molestias nemo temporibus voluptatum architecto ex. Rem enim non nostrum minus doloremque, suscipit ad vero iste cumque velit obcaecati aut?\nAssumenda quibusdam nostrum aspernatur delectus laboriosam veniam, alias voluptatem vel itaque iure deserunt ullam doloremque nobis, distinctio recusandae nulla facilis ipsam repellat debitis quae, ea voluptatem itaque delectus porro, repudiandae cum assumenda rerum libero labore ducimus dignissimos? Optio illo sint iusto animi distinctio, quos praesentium sed saepe aliquid tenetur aspernatur, odio unde magnam a quisquam facere magni inventore iure totam officiis. Quibusdam nulla delectus consectetur rem cumque nam, ipsam voluptatibus ea facilis numquam veniam mollitia alias, provident reprehenderit ullam itaque, dolorem doloremque voluptas laboriosam, hic ipsam temporibus eum aperiam sit. Iste unde dolorem cum quasi magni, cum veniam commodi quo iusto inventore doloribus autem magnam, sequi ipsa unde deleniti eum eos ut velit voluptatem atque debitis, qui et ducimus ipsam, totam blanditiis fugiat.\nFugiat quod debitis harum esse quidem similique accusamus nostrum, blanditiis ex delectus corrupti eius impedit ut est quis explicabo, delectus quasi nostrum molestiae consectetur velit totam omnis rerum esse odit repudiandae, nemo dicta magni magnam explicabo debitis nobis adipisci. Minima reiciendis et deleniti possimus ex provident vero doloribus iure, perspiciatis quidem velit nemo necessitatibus consectetur fuga veniam laborum et dicta.\nAliquam asperiores ducimus autem perferendis cum vero fugiat ut tempore, excepturi rem accusantium corrupti omnis in repudiandae nobis sunt inventore sit, atque non facilis nulla ratione odit explicabo tempora, rem perspiciatis earum sit expedita? Sint quos dignissimos quasi, maxime consequuntur sit quibusdam non at, quae accusantium nostrum deleniti nisi amet aspernatur ad blanditiis tempore harum quasi, cum sint facilis cumque quaerat officiis assumenda dicta sapiente eum, ut fugit eveniet distinctio porro maxime. Possimus iste quidem eligendi officiis assumenda, natus exercitationem nostrum pariatur veritatis molestiae accusantium maxime minus. Cum perspiciatis impedit, explicabo vel quisquam, fugit asperiores exercitationem minima culpa magni.\nEt soluta explicabo esse, earum enim dolor consequuntur ex a fugiat, at quis ab ut illo error minus? Vitae reiciendis officiis at obcaecati facilis eos, quasi architecto illum similique ipsum sint est fugiat libero recusandae accusamus, error debitis facilis asperiores sint nisi porro corporis recusandae accusantium iure fuga, quibusdam facilis ducimus porro?\nInventore amet odit, voluptate sint earum nesciunt, illum do ...

# %%
# 2. Generation Parameters
# max_words: The total number of words in the longest text entry.
# word_interval: The number of new words to add for each subsequent row.
max_words = 10000 
word_interval = 5 # The number of words to add for each new row

# 3. Prepare the data generation
words = lorem_ipsum_source.split()
dataset_rows = []

# Ensure the requested number of words does not exceed the source text length
if max_words > len(words):
    print(f"Warning: max_words ({max_words}) exceeds the number of available words in the source text ({len(words)}).")
    print(f"The dataset will be capped at {len(words)} rows.")
    max_words = len(words)

# 4. Loop to generate each row of the dataset using the specified interval
# The range function now starts at 'word_interval' and steps by 'word_interval'.
for i in range(word_interval, max_words + 1, word_interval):
    # Select the first 'i' words from the source list
    current_words_list = words[:i]
    
    # Join the words to form the text for the current row
    text = " ".join(current_words_list)
    
    # Get the last word
    last_word = current_words_list[-1]
    
    # Append the generated data as a dictionary to our list
    dataset_rows.append({
        'text': text,
        'char_count': len(text),
        'word_count': i,
        'last_word': last_word
    })

# 5. Create the final pandas DataFrame
df_lorem = pd.DataFrame(dataset_rows)

# 6. Display the head and tail of the generated DataFrame to verify
print(f"Successfully generated a dataset with {len(df_lorem)} rows.")
print("\nFirst 5 rows:")
display(df_lorem.head())

print("\nLast 5 rows:")
display(df_lorem.tail())
# Out:
# Successfully generated a dataset with 2000 rows.
#
# First 5 rows:
#                                                 text  char_count  word_count  \
# 0                        Lorem ipsum dolor sit amet,          27           5
# 1  Lorem ipsum dolor sit amet, consectetur adipis...          64          10
# 2  Lorem ipsum dolor sit amet, consectetur adipis...         100          15
# 3  Lorem ipsum dolor sit amet, consectetur adipis...         127          20
# 4  Lorem ipsum dolor sit amet, consectetur adipis...         154          25
#
#   last_word
# 0     amet,
# 1        do
# 2    labore
# 3        Ut
# 4      quis
# Last 5 rows:
#                                                    text  char_count  \
# 1995  Lorem ipsum dolor sit amet, consectetur adipis...       75332
# 1996  Lorem ipsum dolor sit amet, consectetur adipis...       75374
# 1997  Lorem ipsum dolor sit amet, consectetur adipis...       75407
# 1998  Lorem ipsum dolor sit amet, consectetur adipis...       75439
# 1999  Lorem ipsum dolor sit amet, consectetur adipis...       75473
#
#       word_count last_word
# 1995        9980     fugit
# 1996        9985     neque
# 1997        9990        id
# 1998        9995     magni
# 1999       10000  incidunt

# %%
# 7. Export the DataFrame to a CSV file
output_filename = '../dataset/lorem_ipsum_dataset.csv'
df_lorem.to_csv(output_filename, index=False)

print(f"DataFrame successfully exported to '{output_filename}'.")
# Out:
# DataFrame successfully exported to '../dataset/lorem_ipsum_dataset.csv'.
